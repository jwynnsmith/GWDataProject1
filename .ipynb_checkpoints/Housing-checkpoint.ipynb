# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Store filepath in a variable
housing_file = "DC_HousingN1_39.csv"
cluster_file = "clusters_names.csv"

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
# This is now a data frame
housing_df = pd.read_csv(housing_file, encoding="ISO-8859-1")
housing_df.head()
# Out:
#   Cluster  Year  Sales of Single-Family Homes  \
# 0      N1  1995                            34
# 1      N1  1996                            37
# 2      N1  1997                            50
# 3      N1  1998                            63
# 4      N1  1999                            55
#
#   Price of Single-Family Homes (2016 $) Food stamp recipients
# 0                               410,000                   NaN
# 1                               365,000                   NaN
# 2                               501,000                   NaN
# 3                               538,000                   NaN
# 4                               522,000                   NaN

# %%
name_df = pd.read_csv(cluster_file, encoding="ISO-8859-1")
name_df.head()
# Out:
#                                             Clusters
# 0   ÊÊKalorama Heights, Adams Morgan, Lanier Heights
# 1  ÊÊColumbia Heights, Mt. Pleasant, Pleasant Pla...
# 2   ÊÊHoward University, Le Droit Park, Cardozo/Shaw
# 3                  ÊÊGeorgetown, Burleith/Hillandale
# 4                      ÊÊWest End, Foggy Bottom, GWU

# %%
name_df.style.set_properties(**{'text-align': 'left'})

#name_df["Clusters"] = name_df["Clusters"].str[2:]

name_df
# Out:
#                                              Clusters
# 0      Kalorama Heights, Adams Morgan, Lanier Heights
# 1   Columbia Heights, Mt. Pleasant, Pleasant Plain...
# 2      Howard University, Le Droit Park, Cardozo/Shaw
# 3                     Georgetown, Burleith/Hillandale
# 4                         West End, Foggy Bottom, GWU
# 5          Dupont Circle, Connecticut Avenue/K Street
# 6                                  Shaw, Logan Circle
# 7   Downtown, Chinatown, Penn Quarters, Mount Vern...
# 8   Southwest Employment Area, Southwest/Waterfron...
# 9               Hawthorne, Barnaby Woods, Chevy Chase
# 10  Friendship Heights, American University Park, ...
# 11       North Cleveland Park, Forest Hills, Van Ness
# 12  Spring Valley, Palisades, Wesley Heights, Foxh...
# 13     Cathedral Heights, McLean Gardens, Glover Park
# 14  Cleveland Park, Woodley Park, Massachusetts Av...
# 15  Colonial Village, Shepherd Park, North Portal ...
# 16                     Takoma, Brightwood, Manor Park
# 17               Brightwood Park, Crestwood, Petworth
# 18  Lamond Riggs, Queens Chapel, Fort Totten, Plea...
# 19  North Michigan Park, Michigan Park, University...
# 20  Edgewood, Bloomingdale, Truxton Circle, Eckington
# 21                      Brookland, Brentwood, Langdon
# 22     Ivy City, Arboretum, Trinidad, Carver Langston
# 23                   Woodridge, Fort Lincoln, Gateway
# 24    NoMa, Union Station, Stanton Park, Kingman Park
# 25                         Capitol Hill, Lincoln Park
# 26                          Near Southeast, Navy Yard
# 27                                 Historic Anacostia
# 28                       Eastland Gardens, Kenilworth
# 29               Mayfair, Hillbrook, Mahaning Heights
# 30  Deanwood, Burrville, Grant Park, Lincoln Heigh...
# 31      River Terrace, Benning, Greenway, Fort Dupont
# 32    Capitol View, Marshall Heights, Benning Heights
# 33  Twining, Fairlawn, Randle Highlands, Penn Bran...
# 34  Fairfax Village, Naylor Gardens, Hillcrest, Su...
# 35  Woodland/Fort Stanton, Garfield Heights, Knox ...
# 36                  Sheridan, Barry Farm, Buena Vista
# 37                          Douglass, Shipley Terrace
# 38   Congress Heights, Bellevue, Washington Highlands

# %%
housing_df["Single-Family Homes Median Price (2016 $)"] = housing_df["Price of Single-Family Homes (2016 $)"].str.replace(',', '').dropna().astype("int")
housing_df.head()
# Out:
#   Cluster  Year  Sales of Single-Family Homes  \
# 0      N1  1995                            34
# 1      N1  1996                            37
# 2      N1  1997                            50
# 3      N1  1998                            63
# 4      N1  1999                            55
#
#   Price of Single-Family Homes (2016 $) Food stamp recipients  \
# 0                               410,000                   NaN
# 1                               365,000                   NaN
# 2                               501,000                   NaN
# 3                               538,000                   NaN
# 4                               522,000                   NaN
#
#    Single-Family Homes Median Price (2016 $)
# 0                                   410000.0
# 1                                   365000.0
# 2                                   501000.0
# 3                                   538000.0
# 4                                   522000.0

# %%
housing_df["Food Stamp Count"] = housing_df["Food stamp recipients"].dropna().str.replace(',', '').dropna().astype("int")
housing_df.head()
# Out:
#   Cluster  Year  Sales of Single-Family Homes  \
# 0      N1  1995                            34
# 1      N1  1996                            37
# 2      N1  1997                            50
# 3      N1  1998                            63
# 4      N1  1999                            55
#
#   Price of Single-Family Homes (2016 $) Food stamp recipients  \
# 0                               410,000                   NaN
# 1                               365,000                   NaN
# 2                               501,000                   NaN
# 3                               538,000                   NaN
# 4                               522,000                   NaN
#
#    Single-Family Homes Median Price (2016 $)  Food Stamp Count
# 0                                   410000.0               NaN
# 1                                   365000.0               NaN
# 2                                   501000.0               NaN
# 3                                   538000.0               NaN
# 4                                   522000.0               NaN

# %%
neighborhood_stats_df = housing_df[["Cluster", "Year", "Sales of Single-Family Homes", "Single-Family Homes Median Price (2016 $)", "Food Stamp Count"]]
neighborhood_stats_df.head()
# Out:
#   Cluster  Year  Sales of Single-Family Homes  \
# 0      N1  1995                            34
# 1      N1  1996                            37
# 2      N1  1997                            50
# 3      N1  1998                            63
# 4      N1  1999                            55
#
#    Single-Family Homes Median Price (2016 $)  Food Stamp Count
# 0                                   410000.0               NaN
# 1                                   365000.0               NaN
# 2                                   501000.0               NaN
# 3                                   538000.0               NaN
# 4                                   522000.0               NaN

# %%
neighborhood_stats_df.pivot("Year", "Cluster", "Sales of Single-Family Homes").plot(kind="line", marker="o", 
    grid = True).legend(bbox_to_anchor=(1, 1), title = "Neighborhood Clusters")

# Set the label for the y-axis
plt.ylabel("Sales of Single-Family Homes")
plt.title("# of Home Sales Per Neighborhood Cluster")

#y_limit = plt.ylim(round(min(overall_scores)-3),round(max(overall_scores)+3))

#print min and max for y-axis
#print(y_limit)

#Tight fit layout
#plt.tight_layout()

# Save Figure
plt.savefig("Number_of_Homes.png")

# Show plot
plt.show()

# %%
neighborhood_stats_df.pivot("Year", "Cluster", "Single-Family Homes Median Price (2016 $)").plot(kind="line", marker="o", 
    legend = "best", grid = True).legend(bbox_to_anchor=(1, 1), title = "Neighborhood Clusters")

# Set the label for the y-axis
plt.ylabel("Single-Family Homes Median Price (2016 $)")

plt.title("Median Sales Price Per Neighborhood Cluster")

#y_limit = plt.ylim(round(min(overall_scores)-3),round(max(overall_scores)+3))

#print min and max for y-axis
#print(y_limit)

#Tight fit layout
#plt.tight_layout()

# Save Figure
plt.savefig("Price_of_Homes.png")

# Show plot
plt.show()

# %%
neighborhood_stats_df.pivot("Year", "Cluster", "Food Stamp Count").plot(kind="line", marker="o", 
    legend = "best", grid = True).legend(bbox_to_anchor=(1, 1), title = "Neighborhood Clusters")

# Set the label for the y-axis
plt.ylabel("Food Stamp Count")

plt.title("Food Stamp Recipients")

plt.xlim(1994,2017)
#y_limit = plt.ylim(round(min(overall_scores)-3),round(max(overall_scores)+3))

#print min and max for y-axis
#print(y_limit)

#Tight fit layout
#plt.tight_layout()

# Save Figure
plt.savefig("Food_Stamps.png")

# Show plot
plt.show()

# %%
cluster_count = neighborhood_stats_df["Cluster"].nunique()
cluster_count
# Out:
# 39

# %%
for num in range(1,cluster_count+1):
    #Query individual column in dataframe
    #n_df = neighborhood_stats_df.query('Cluster == ["N1"]')
    
    #Make query dynamic over multiple dataframes
    n_df = neighborhood_stats_df.query(f'Cluster == ["N{num}"]')
    
    #obtain correlation between number of sales and Median home price
    ct_sales_corr = n_df["Sales of Single-Family Homes"].corr(n_df["Single-Family Homes Median Price (2016 $)"])
    
    #
    
    #print(n_df)
    print(ct_sales_corr)
    #Another way to correlate between two columns
    #print(n_df[["Sales of Single-Family Homes", "Single-Family Homes Median Price (2016 $)"]].corr())
# Out:
# -0.6099715147739252
# -0.7007365870561917
# -0.4328068998300141
# -0.6254122130187743
# -0.03164129360897677
# -0.5614692350987529
# -0.616025341326934
# nan
# -0.08580579082039802
# -0.5653750787384781
# -0.629902409933951
# -0.6629478629115221
# -0.5403209574731074
# -0.4759384159599618
# -0.44524578598877934
# -0.5423491646306476
# -0.1916893229597367
# -0.28784932439731964
# 0.1970840038661867
# -0.046791485420452784
# -0.3243953811936925
# -0.3391824702600544
# 0.003944900864448205
# 0.48410516412307747
# -0.44951066220309277
# -0.453117996463642
# 0.49204558680121874
# -0.14900313982085864
# 0.24879954709073301
# -0.38753628555235026
# -0.1436879925262245
# -0.326245280527253
# 0.2725786735594736
# -0.5632019082785035
# -0.590237517318728
# 0.16866639669130304
# -0.03847789151082104
# 0.5800264689494957
# -0.12118765033938327
